# %% [markdown]
# # Python 控制流
#
# 本教程将学习Python中的控制流语句，包括条件语句和循环语句。
#
# ## 1. if 条件语句

# %%
# 简单的if语句
age = 18
if age >= 18:
    print("您已经成年了")
# Out:
# 您已经成年了

# %%
# if-else语句
score = 85
if score >= 60:
    print("及格了")
else:
    print("不及格")
# Out:
# 及格了

# %%
# if-elif-else语句
score = 85
if score >= 90:
    grade = "优秀"
elif score >= 80:
    grade = "良好"
elif score >= 70:
    grade = "中等"
elif score >= 60:
    grade = "及格"
else:
    grade = "不及格"

print(f"分数: {score}, 等级: {grade}")
# Out:
# 分数: 85, 等级: 良好

# %% [markdown]
# ## 2. for 循环

# %%
# 基本的for循环 - 遍历列表
fruits = ["苹果", "香蕉", "橘子"]
for fruit in fruits:
    print(f"水果: {fruit}")
# Out:
# 水果: 苹果
# 水果: 香蕉
# 水果: 橘子

# %%
# 使用range()函数
print("打印0到4:")
for i in range(5):
    print(i)

print("\n打印2到5:")
for i in range(2, 6):
    print(i)

print("\n打印0到10，步长为2:")
for i in range(0, 11, 2):
    print(i)
# Out:
# 打印0到4:
# 0
# 1
# 2
# 3
# 4
#
# 打印2到5:
# 2
# 3
# 4
# 5
#
# 打印0到10，步长为2:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# 遍历字符串
word = "Python"
for char in word:
    print(char)
# Out:
# P
# y
# t
# h
# o
# n

# %%
# enumerate()函数 - 同时获取索引和值
fruits = ["苹果", "香蕉", "橘子"]
for index, fruit in enumerate(fruits):
    print(f"索引 {index}: {fruit}")
# Out:
# 索引 0: 苹果
# 索引 1: 香蕉
# 索引 2: 橘子

# %% [markdown]
# ## 3. while 循环

# %%
# 基本的while循环
count = 0
while count < 5:
    print(f"计数: {count}")
    count += 1
# Out:
# 计数: 0
# 计数: 1
# 计数: 2
# 计数: 3
# 计数: 4

# %%
# while循环的实用示例 - 计算1到10的和
sum_num = 0
num = 1
while num <= 10:
    sum_num += num
    num += 1
print(f"1到10的和: {sum_num}")
# Out:
# 1到10的和: 55

# %% [markdown]
# ## 4. break 和 continue

# %%
# break - 跳出循环
print("使用break跳出循环:")
for i in range(10):
    if i == 5:
        break  # 当i等于5时跳出循环
    print(i)
print("循环结束")
# Out:
# 使用break跳出循环:
# 0
# 1
# 2
# 3
# 4
# 循环结束

# %%
# continue - 跳过本次循环，继续下一次循环
print("使用continue跳过偶数:")
for i in range(10):
    if i % 2 == 0:  # 如果是偶数
        continue  # 跳过本次循环
    print(i)
# Out:
# 使用continue跳过偶数:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ## 5. 嵌套循环

# %%
# 嵌套循环 - 打印乘法表
print("九九乘法表:")
for i in range(1, 10):
    for j in range(1, i + 1):
        print(f"{j}×{i}={i*j}", end="\t")
    print()  # 换行
# Out:
# 九九乘法表:
# 1×1=1
# 1×2=2	2×2=4
# 1×3=3	2×3=6	3×3=9
# 1×4=4	2×4=8	3×4=12	4×4=16
# 1×5=5	2×5=10	3×5=15	4×5=20	5×5=25
# 1×6=6	2×6=12	3×6=18	4×6=24	5×6=30	6×6=36
# 1×7=7	2×7=14	3×7=21	4×7=28	5×7=35	6×7=42	7×7=49
# 1×8=8	2×8=16	3×8=24	4×8=32	5×8=40	6×8=48	7×8=56	8×8=64
# 1×9=9	2×9=18	3×9=27	4×9=36	5×9=45	6×9=54	7×9=63	8×9=72	9×9=81

# %%
if 1+1==2 and 2+2==4:
    print("1+1=2 and 2+2=4")
# Out:
# 1+1=2 and 2+2=4
